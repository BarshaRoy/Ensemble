# %%
# !pip install visualkeras
import os
import warnings
import itertools
import cv2
import seaborn as sns
import pandas as pd
import numpy  as np
from PIL import Image
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from collections import Counter

import tensorflow as tf
import tensorflow_addons as tfa
import visualkeras
import plotly.express as px
import matplotlib.pyplot as plt
from sklearn.metrics import multilabel_confusion_matrix
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import plot_model
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from sklearn.model_selection   import train_test_split
from keras.preprocessing.image import ImageDataGenerator

warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from visualkeras) (9.5.0)
# Requirement already satisfied: numpy>=1.18.1 in /opt/conda/lib/python3.10/site-packages (from visualkeras) (1.23.5)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.16-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.0/993.0 kB 15.0 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.16 visualkeras-0.0.2
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
folder_path = "../input/leukemia/Original"
Benign = os.listdir(folder_path + '/Benign/')
Early = os.listdir(folder_path + '/Early/')
Pre = os.listdir(folder_path + '/Pre/')
Pro = os.listdir(folder_path + '/Pro/')
dataset=[]
lab=[]

for image_name in Benign:
    image=cv2.imread(folder_path + '/Benign/' + image_name)
    image=Image.fromarray(image,'RGB')
    image=image.resize((240,240))
    dataset.append(np.array(image))
    lab.append(0)
    
for image_name in Early:
    image=cv2.imread(folder_path + '/Early/' + image_name)
    image=Image.fromarray(image,'RGB')
    image=image.resize((240,240))
    dataset.append(np.array(image))
    lab.append(1)
for image_name in Pre:
    image=cv2.imread(folder_path + '/Pre/' + image_name)
    image=Image.fromarray(image,'RGB')
    image=image.resize((240,240))
    dataset.append(np.array(image))
    lab.append(2)
for image_name in Pro:
    image=cv2.imread(folder_path + '/Pro/' + image_name)
    image=Image.fromarray(image,'RGB')
    image=image.resize((240,240))
    dataset.append(np.array(image))
    lab.append(3)

# %%
dataset = np.array(dataset)
lab = np.array(lab)
print(dataset.shape, lab.shape)
# Out:
# (3256, 240, 240, 3) (3256,)

# %%
from sklearn.model_selection import train_test_split
# !pip install split_folders
import splitfolders
import os
import shutil
from PIL import Image


# Set the random state value
random_state = 42

# Split the data into train, validation, and test sets using arrays
x_train_val, x_test, y_train_val, y_test = train_test_split(dataset, lab, test_size=0.2, shuffle=True, random_state=random_state)
x_train, x_val, y_train, y_val = train_test_split(x_train_val, y_train_val, test_size=0.25, shuffle=True, random_state=random_state)
print(f"train shape: {x_train.shape}- y_train shape: {y_train.shape}")
print(f"test shape: {x_test.shape}- y_test shape: {y_test.shape}")
# Out:
# Collecting split_folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split_folders
# Successfully installed split_folders-0.5.1
# train shape: (1953, 240, 240, 3)- y_train shape: (1953,)
# test shape: (652, 240, 240, 3)- y_test shape: (652,)

# %%
epochs = 100
pic_size = 240
np.random.seed(42)
tf.random.set_seed(42)
def plot_state(state):
    plt.figure(figsize= (12,12))
    for i in range(1, 5, 1):
        plt.subplot(3,3,i)
        img = load_img(folder_path + "/" + state + "/" + os.listdir(folder_path + "/" + state)[i], target_size=(pic_size, pic_size))
        plt.imshow(img)   
    plt.show()
plot_state('Early')

# %%
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 32
num_epochs = 100
image_size = 240  # We'll resize input images to this size
patch_size = 20  # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 8
mlp_head_units = [2048, 1024]  # Size of the dense layers of the final classifier

# %%
import tensorflow as tf
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import numpy as np

class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# %%
plt.figure(figsize=(8, 8))
image = x_train[np.random.choice(range(x_train.shape[0]))]
plt.imshow(image.astype("uint8"))

resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(8, 8))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype("uint8"))
    plt.axis("off")
# Out:
# Image size: 240 X 240
# Patch size: 20 X 20
# Patches per image: 144
# Elements per patch: 1200

# %%
data_augmentation = tf.keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
class PatchEncoder(tf.keras.layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
def create_vit_classifier():
    inputs = layers.Input(shape=(240, 240, 3))
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.2
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(4)(features)
    # Create the Keras model.
    model = tf.keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
import tensorflow as tf
import tensorflow_addons as tfa
from keras.models import save_model
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
        metrics=[
            tf.keras.metrics.CategoricalAccuracy(name="accuracy"),
            tf.keras.metrics.TopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    checkpoint_filepath = "/tmp/checkpoint"
    checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        x=x_train,
        y=tf.keras.utils.to_categorical(y_train, num_classes=4),
        batch_size=batch_size,
        epochs=num_epochs,
        validation_data=(x_val, tf.keras.utils.to_categorical(y_val, num_classes=4)),
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(x_test, tf.keras.utils.to_categorical(y_test, num_classes=4))
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    # Save the model
    #model.save("I:/8th semester/Thesis+Seminar/saved model/vit_model.h5")
    #print("ViT model saved successfully!")

    return history

vit_classifier = create_vit_classifier()
vit_history = run_experiment(vit_classifier)
# Out:
# Epoch 1/100
# 62/62 [==============================] - 22s 133ms/step - loss: 2.3380 - accuracy: 0.6795 - top-5-accuracy: 1.0000 - val_loss: 0.8115 - val_accuracy: 0.7665 - val_top-5-accuracy: 1.0000
# Epoch 2/100
# 62/62 [==============================] - 7s 109ms/step - loss: 0.8534 - accuracy: 0.7568 - top-5-accuracy: 1.0000 - val_loss: 0.4382 - val_accuracy: 0.8679 - val_top-5-accuracy: 1.0000
# Epoch 3/100
# 62/62 [==============================] - 6s 104ms/step - loss: 0.4378 - accuracy: 0.8669 - top-5-accuracy: 1.0000 - val_loss: 0.3529 - val_accuracy: 0.8879 - val_top-5-accuracy: 1.0000
# Epoch 4/100
# 62/62 [==============================] - 6s 105ms/step - loss: 0.4544 - accuracy: 0.8740 - top-5-accuracy: 1.0000 - val_loss: 0.2120 - val_accuracy: 0.9355 - val_top-5-accuracy: 1.0000
# Epoch 5/100
# 62/62 [==============================] - 6s 103ms/step - loss: 0.4721 - accuracy: 0.8705 - top-5-accuracy: 1.0000 - val_loss: 0.1243 - val_accuracy: 0.9555 - val_top-5-accuracy: 1.0000
# Epoch 6/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.2692 - accuracy: 0.9186 - top-5-accuracy: 1.0000 - val_loss: 0.1451 - val_accuracy: 0.9524 - val_top-5-accuracy: 1.0000
# Epoch 7/100
# 62/62 [==============================] - 7s 107ms/step - loss: 0.1642 - accuracy: 0.9462 - top-5-accuracy: 1.0000 - val_loss: 0.0618 - val_accuracy: 0.9770 - val_top-5-accuracy: 1.0000
# Epoch 8/100
# 62/62 [==============================] - 7s 105ms/step - loss: 0.1479 - accuracy: 0.9519 - top-5-accuracy: 1.0000 - val_loss: 0.0475 - val_accuracy: 0.9862 - val_top-5-accuracy: 1.0000
# Epoch 9/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.1154 - accuracy: 0.9672 - top-5-accuracy: 1.0000 - val_loss: 0.0495 - val_accuracy: 0.9831 - val_top-5-accuracy: 1.0000
# Epoch 10/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.1322 - accuracy: 0.9621 - top-5-accuracy: 1.0000 - val_loss: 0.1126 - val_accuracy: 0.9601 - val_top-5-accuracy: 1.0000
# Epoch 11/100
# 62/62 [==============================] - 5s 82ms/step - loss: 0.1379 - accuracy: 0.9575 - top-5-accuracy: 1.0000 - val_loss: 0.0557 - val_accuracy: 0.9800 - val_top-5-accuracy: 1.0000
# Epoch 12/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.1792 - accuracy: 0.9457 - top-5-accuracy: 1.0000 - val_loss: 0.1295 - val_accuracy: 0.9539 - val_top-5-accuracy: 1.0000
# Epoch 13/100
# 62/62 [==============================] - 5s 85ms/step - loss: 0.1286 - accuracy: 0.9616 - top-5-accuracy: 1.0000 - val_loss: 0.0504 - val_accuracy: 0.9800 - val_top-5-accuracy: 1.0000
# Epoch 14/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0935 - accuracy: 0.9693 - top-5-accuracy: 1.0000 - val_loss: 0.0450 - val_accuracy: 0.9862 - val_top-5-accuracy: 1.0000
# Epoch 15/100
# 62/62 [==============================] - 5s 82ms/step - loss: 0.1105 - accuracy: 0.9718 - top-5-accuracy: 1.0000 - val_loss: 0.4204 - val_accuracy: 0.8894 - val_top-5-accuracy: 1.0000
# Epoch 16/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.3585 - accuracy: 0.9073 - top-5-accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9631 - val_top-5-accuracy: 1.0000
# Epoch 17/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.1823 - accuracy: 0.9498 - top-5-accuracy: 1.0000 - val_loss: 0.2183 - val_accuracy: 0.9278 - val_top-5-accuracy: 1.0000
# Epoch 18/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.2009 - accuracy: 0.9508 - top-5-accuracy: 1.0000 - val_loss: 0.1007 - val_accuracy: 0.9647 - val_top-5-accuracy: 1.0000
# Epoch 19/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.1051 - accuracy: 0.9657 - top-5-accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9816 - val_top-5-accuracy: 1.0000
# Epoch 20/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.1234 - accuracy: 0.9636 - top-5-accuracy: 1.0000 - val_loss: 0.0908 - val_accuracy: 0.9647 - val_top-5-accuracy: 1.0000
# Epoch 21/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0863 - accuracy: 0.9729 - top-5-accuracy: 1.0000 - val_loss: 0.0353 - val_accuracy: 0.9846 - val_top-5-accuracy: 1.0000
# Epoch 22/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.2236 - accuracy: 0.9488 - top-5-accuracy: 1.0000 - val_loss: 0.0688 - val_accuracy: 0.9739 - val_top-5-accuracy: 1.0000
# Epoch 23/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.1538 - accuracy: 0.9570 - top-5-accuracy: 1.0000 - val_loss: 0.0675 - val_accuracy: 0.9800 - val_top-5-accuracy: 1.0000
# Epoch 24/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.0952 - accuracy: 0.9688 - top-5-accuracy: 1.0000 - val_loss: 0.0506 - val_accuracy: 0.9816 - val_top-5-accuracy: 1.0000
# Epoch 25/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.0778 - accuracy: 0.9754 - top-5-accuracy: 1.0000 - val_loss: 0.2332 - val_accuracy: 0.9570 - val_top-5-accuracy: 1.0000
# Epoch 26/100
# 62/62 [==============================] - 5s 84ms/step - loss: 0.1400 - accuracy: 0.9657 - top-5-accuracy: 1.0000 - val_loss: 0.0630 - val_accuracy: 0.9785 - val_top-5-accuracy: 1.0000
# Epoch 27/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.1260 - accuracy: 0.9611 - top-5-accuracy: 1.0000 - val_loss: 0.0568 - val_accuracy: 0.9831 - val_top-5-accuracy: 1.0000
# Epoch 28/100
# 62/62 [==============================] - 5s 78ms/step - loss: 0.0651 - accuracy: 0.9795 - top-5-accuracy: 1.0000 - val_loss: 0.0564 - val_accuracy: 0.9862 - val_top-5-accuracy: 1.0000
# Epoch 29/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0720 - accuracy: 0.9770 - top-5-accuracy: 1.0000 - val_loss: 0.0596 - val_accuracy: 0.9846 - val_top-5-accuracy: 1.0000
# Epoch 30/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0651 - accuracy: 0.9795 - top-5-accuracy: 1.0000 - val_loss: 0.0699 - val_accuracy: 0.9846 - val_top-5-accuracy: 1.0000
# Epoch 31/100
# 62/62 [==============================] - 5s 82ms/step - loss: 0.1433 - accuracy: 0.9631 - top-5-accuracy: 1.0000 - val_loss: 0.1128 - val_accuracy: 0.9616 - val_top-5-accuracy: 1.0000
# Epoch 32/100
# 62/62 [==============================] - 6s 103ms/step - loss: 0.0711 - accuracy: 0.9749 - top-5-accuracy: 1.0000 - val_loss: 0.0360 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 33/100
# 62/62 [==============================] - 6s 102ms/step - loss: 0.0478 - accuracy: 0.9841 - top-5-accuracy: 1.0000 - val_loss: 0.0285 - val_accuracy: 0.9908 - val_top-5-accuracy: 1.0000
# Epoch 34/100
# 62/62 [==============================] - 5s 78ms/step - loss: 0.0663 - accuracy: 0.9846 - top-5-accuracy: 1.0000 - val_loss: 0.0967 - val_accuracy: 0.9770 - val_top-5-accuracy: 1.0000
# Epoch 35/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.1585 - accuracy: 0.9698 - top-5-accuracy: 1.0000 - val_loss: 0.0534 - val_accuracy: 0.9800 - val_top-5-accuracy: 1.0000
# Epoch 36/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.1266 - accuracy: 0.9749 - top-5-accuracy: 1.0000 - val_loss: 0.0571 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 37/100
# 62/62 [==============================] - 5s 78ms/step - loss: 0.0729 - accuracy: 0.9775 - top-5-accuracy: 1.0000 - val_loss: 0.0535 - val_accuracy: 0.9816 - val_top-5-accuracy: 1.0000
# Epoch 38/100
# 62/62 [==============================] - 6s 104ms/step - loss: 0.0499 - accuracy: 0.9862 - top-5-accuracy: 1.0000 - val_loss: 0.0229 - val_accuracy: 0.9923 - val_top-5-accuracy: 1.0000
# Epoch 39/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0640 - accuracy: 0.9816 - top-5-accuracy: 1.0000 - val_loss: 0.0695 - val_accuracy: 0.9724 - val_top-5-accuracy: 1.0000
# Epoch 40/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.0823 - accuracy: 0.9718 - top-5-accuracy: 1.0000 - val_loss: 0.0753 - val_accuracy: 0.9708 - val_top-5-accuracy: 1.0000
# Epoch 41/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.1753 - accuracy: 0.9590 - top-5-accuracy: 1.0000 - val_loss: 0.0499 - val_accuracy: 0.9831 - val_top-5-accuracy: 1.0000
# Epoch 42/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.0636 - accuracy: 0.9775 - top-5-accuracy: 1.0000 - val_loss: 0.0383 - val_accuracy: 0.9862 - val_top-5-accuracy: 1.0000
# Epoch 43/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.0667 - accuracy: 0.9867 - top-5-accuracy: 1.0000 - val_loss: 0.0357 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 44/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.1187 - accuracy: 0.9677 - top-5-accuracy: 1.0000 - val_loss: 0.0656 - val_accuracy: 0.9816 - val_top-5-accuracy: 1.0000
# Epoch 45/100
# 62/62 [==============================] - 5s 85ms/step - loss: 0.1004 - accuracy: 0.9795 - top-5-accuracy: 1.0000 - val_loss: 0.1104 - val_accuracy: 0.9754 - val_top-5-accuracy: 1.0000
# Epoch 46/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.0662 - accuracy: 0.9754 - top-5-accuracy: 1.0000 - val_loss: 0.0530 - val_accuracy: 0.9816 - val_top-5-accuracy: 1.0000
# Epoch 47/100
# 62/62 [==============================] - 5s 77ms/step - loss: 0.0462 - accuracy: 0.9887 - top-5-accuracy: 1.0000 - val_loss: 0.0438 - val_accuracy: 0.9923 - val_top-5-accuracy: 1.0000
# Epoch 48/100
# 62/62 [==============================] - 5s 78ms/step - loss: 0.0516 - accuracy: 0.9862 - top-5-accuracy: 1.0000 - val_loss: 0.0603 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 49/100
# 62/62 [==============================] - 5s 76ms/step - loss: 0.0543 - accuracy: 0.9872 - top-5-accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 0.9908 - val_top-5-accuracy: 1.0000
# Epoch 50/100
# 62/62 [==============================] - 5s 78ms/step - loss: 0.0550 - accuracy: 0.9872 - top-5-accuracy: 1.0000 - val_loss: 0.0640 - val_accuracy: 0.9846 - val_top-5-accuracy: 1.0000
# Epoch 51/100
# 62/62 [==============================] - 6s 92ms/step - loss: 0.0901 - accuracy: 0.9836 - top-5-accuracy: 1.0000 - val_loss: 0.0704 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 52/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.0611 - accuracy: 0.9841 - top-5-accuracy: 1.0000 - val_loss: 0.0265 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 53/100
# 62/62 [==============================] - 6s 102ms/step - loss: 0.0391 - accuracy: 0.9882 - top-5-accuracy: 1.0000 - val_loss: 0.0185 - val_accuracy: 0.9939 - val_top-5-accuracy: 1.0000
# Epoch 54/100
# 62/62 [==============================] - 6s 103ms/step - loss: 0.0452 - accuracy: 0.9862 - top-5-accuracy: 1.0000 - val_loss: 0.0180 - val_accuracy: 0.9954 - val_top-5-accuracy: 1.0000
# Epoch 55/100
# 62/62 [==============================] - 5s 78ms/step - loss: 0.0277 - accuracy: 0.9908 - top-5-accuracy: 1.0000 - val_loss: 0.0375 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 56/100
# 62/62 [==============================] - 5s 78ms/step - loss: 0.0771 - accuracy: 0.9800 - top-5-accuracy: 1.0000 - val_loss: 0.0296 - val_accuracy: 0.9862 - val_top-5-accuracy: 1.0000
# Epoch 57/100
# 62/62 [==============================] - 5s 82ms/step - loss: 0.0311 - accuracy: 0.9913 - top-5-accuracy: 1.0000 - val_loss: 0.0346 - val_accuracy: 0.9908 - val_top-5-accuracy: 1.0000
# Epoch 58/100
# 62/62 [==============================] - 5s 78ms/step - loss: 0.0320 - accuracy: 0.9903 - top-5-accuracy: 1.0000 - val_loss: 0.0275 - val_accuracy: 0.9892 - val_top-5-accuracy: 1.0000
# Epoch 59/100
# 62/62 [==============================] - 5s 77ms/step - loss: 0.0656 - accuracy: 0.9862 - top-5-accuracy: 1.0000 - val_loss: 0.0245 - val_accuracy: 0.9908 - val_top-5-accuracy: 1.0000
# Epoch 60/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0696 - accuracy: 0.9857 - top-5-accuracy: 1.0000 - val_loss: 0.0650 - val_accuracy: 0.9862 - val_top-5-accuracy: 1.0000
# Epoch 61/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.1005 - accuracy: 0.9780 - top-5-accuracy: 1.0000 - val_loss: 0.0613 - val_accuracy: 0.9862 - val_top-5-accuracy: 1.0000
# Epoch 62/100
# 62/62 [==============================] - 5s 78ms/step - loss: 0.0800 - accuracy: 0.9749 - top-5-accuracy: 1.0000 - val_loss: 0.0385 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 63/100
# 62/62 [==============================] - 5s 77ms/step - loss: 0.0935 - accuracy: 0.9770 - top-5-accuracy: 1.0000 - val_loss: 0.0356 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 64/100
# 62/62 [==============================] - 5s 83ms/step - loss: 0.0956 - accuracy: 0.9831 - top-5-accuracy: 1.0000 - val_loss: 0.1097 - val_accuracy: 0.9770 - val_top-5-accuracy: 1.0000
# Epoch 65/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0632 - accuracy: 0.9800 - top-5-accuracy: 1.0000 - val_loss: 0.0258 - val_accuracy: 0.9846 - val_top-5-accuracy: 1.0000
# Epoch 66/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0582 - accuracy: 0.9887 - top-5-accuracy: 1.0000 - val_loss: 0.0391 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 67/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.0526 - accuracy: 0.9862 - top-5-accuracy: 1.0000 - val_loss: 0.1375 - val_accuracy: 0.9693 - val_top-5-accuracy: 1.0000
# Epoch 68/100
# 62/62 [==============================] - 5s 78ms/step - loss: 0.0789 - accuracy: 0.9805 - top-5-accuracy: 1.0000 - val_loss: 0.0753 - val_accuracy: 0.9785 - val_top-5-accuracy: 1.0000
# Epoch 69/100
# 62/62 [==============================] - 5s 78ms/step - loss: 0.1711 - accuracy: 0.9585 - top-5-accuracy: 1.0000 - val_loss: 0.1701 - val_accuracy: 0.9570 - val_top-5-accuracy: 1.0000
# Epoch 70/100
# 62/62 [==============================] - 5s 84ms/step - loss: 0.1089 - accuracy: 0.9785 - top-5-accuracy: 1.0000 - val_loss: 0.1271 - val_accuracy: 0.9662 - val_top-5-accuracy: 1.0000
# Epoch 71/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.1000 - accuracy: 0.9770 - top-5-accuracy: 1.0000 - val_loss: 0.0375 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 72/100
# 62/62 [==============================] - 5s 77ms/step - loss: 0.0545 - accuracy: 0.9831 - top-5-accuracy: 1.0000 - val_loss: 0.1033 - val_accuracy: 0.9677 - val_top-5-accuracy: 1.0000
# Epoch 73/100
# 62/62 [==============================] - 5s 78ms/step - loss: 0.0388 - accuracy: 0.9887 - top-5-accuracy: 1.0000 - val_loss: 0.0450 - val_accuracy: 0.9892 - val_top-5-accuracy: 1.0000
# Epoch 74/100
# 62/62 [==============================] - 5s 78ms/step - loss: 0.0482 - accuracy: 0.9857 - top-5-accuracy: 1.0000 - val_loss: 0.0226 - val_accuracy: 0.9892 - val_top-5-accuracy: 1.0000
# Epoch 75/100
# 62/62 [==============================] - 5s 77ms/step - loss: 0.0323 - accuracy: 0.9892 - top-5-accuracy: 1.0000 - val_loss: 0.0197 - val_accuracy: 0.9939 - val_top-5-accuracy: 1.0000
# Epoch 76/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0308 - accuracy: 0.9918 - top-5-accuracy: 1.0000 - val_loss: 0.0268 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 77/100
# 62/62 [==============================] - 5s 83ms/step - loss: 0.0422 - accuracy: 0.9862 - top-5-accuracy: 1.0000 - val_loss: 0.0557 - val_accuracy: 0.9724 - val_top-5-accuracy: 1.0000
# Epoch 78/100
# 62/62 [==============================] - 5s 77ms/step - loss: 0.0552 - accuracy: 0.9852 - top-5-accuracy: 1.0000 - val_loss: 0.0351 - val_accuracy: 0.9862 - val_top-5-accuracy: 1.0000
# Epoch 79/100
# 62/62 [==============================] - 5s 78ms/step - loss: 0.0321 - accuracy: 0.9908 - top-5-accuracy: 1.0000 - val_loss: 0.0286 - val_accuracy: 0.9908 - val_top-5-accuracy: 1.0000
# Epoch 80/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.0268 - accuracy: 0.9923 - top-5-accuracy: 1.0000 - val_loss: 0.0234 - val_accuracy: 0.9954 - val_top-5-accuracy: 1.0000
# Epoch 81/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0216 - accuracy: 0.9928 - top-5-accuracy: 1.0000 - val_loss: 0.0534 - val_accuracy: 0.9862 - val_top-5-accuracy: 1.0000
# Epoch 82/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.0385 - accuracy: 0.9877 - top-5-accuracy: 1.0000 - val_loss: 0.0507 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 83/100
# 62/62 [==============================] - 5s 83ms/step - loss: 0.0453 - accuracy: 0.9898 - top-5-accuracy: 1.0000 - val_loss: 0.0289 - val_accuracy: 0.9908 - val_top-5-accuracy: 1.0000
# Epoch 84/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.0521 - accuracy: 0.9816 - top-5-accuracy: 1.0000 - val_loss: 0.0463 - val_accuracy: 0.9862 - val_top-5-accuracy: 1.0000
# Epoch 85/100
# 62/62 [==============================] - 5s 77ms/step - loss: 0.0465 - accuracy: 0.9857 - top-5-accuracy: 1.0000 - val_loss: 0.1092 - val_accuracy: 0.9739 - val_top-5-accuracy: 1.0000
# Epoch 86/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.1082 - accuracy: 0.9800 - top-5-accuracy: 1.0000 - val_loss: 0.0525 - val_accuracy: 0.9785 - val_top-5-accuracy: 1.0000
# Epoch 87/100
# 62/62 [==============================] - 5s 78ms/step - loss: 0.0460 - accuracy: 0.9852 - top-5-accuracy: 1.0000 - val_loss: 0.0220 - val_accuracy: 0.9939 - val_top-5-accuracy: 1.0000
# Epoch 88/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0306 - accuracy: 0.9877 - top-5-accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 0.9923 - val_top-5-accuracy: 1.0000
# Epoch 89/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0649 - accuracy: 0.9826 - top-5-accuracy: 1.0000 - val_loss: 0.0583 - val_accuracy: 0.9862 - val_top-5-accuracy: 1.0000
# Epoch 90/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.0507 - accuracy: 0.9836 - top-5-accuracy: 1.0000 - val_loss: 0.0705 - val_accuracy: 0.9862 - val_top-5-accuracy: 1.0000
# Epoch 91/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0346 - accuracy: 0.9882 - top-5-accuracy: 1.0000 - val_loss: 0.0558 - val_accuracy: 0.9800 - val_top-5-accuracy: 1.0000
# Epoch 92/100
# 62/62 [==============================] - 5s 78ms/step - loss: 0.0612 - accuracy: 0.9882 - top-5-accuracy: 1.0000 - val_loss: 0.4262 - val_accuracy: 0.9631 - val_top-5-accuracy: 1.0000
# Epoch 93/100
# 62/62 [==============================] - 5s 78ms/step - loss: 0.0754 - accuracy: 0.9836 - top-5-accuracy: 1.0000 - val_loss: 0.1124 - val_accuracy: 0.9677 - val_top-5-accuracy: 1.0000
# Epoch 94/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0492 - accuracy: 0.9857 - top-5-accuracy: 1.0000 - val_loss: 0.0772 - val_accuracy: 0.9816 - val_top-5-accuracy: 1.0000
# Epoch 95/100
# 62/62 [==============================] - 5s 78ms/step - loss: 0.0586 - accuracy: 0.9872 - top-5-accuracy: 1.0000 - val_loss: 0.1605 - val_accuracy: 0.9724 - val_top-5-accuracy: 1.0000
# Epoch 96/100
# 62/62 [==============================] - 5s 83ms/step - loss: 0.1123 - accuracy: 0.9764 - top-5-accuracy: 1.0000 - val_loss: 0.1214 - val_accuracy: 0.9754 - val_top-5-accuracy: 1.0000
# Epoch 97/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.1151 - accuracy: 0.9713 - top-5-accuracy: 1.0000 - val_loss: 0.0433 - val_accuracy: 0.9846 - val_top-5-accuracy: 1.0000
# Epoch 98/100
# 62/62 [==============================] - 5s 78ms/step - loss: 0.0401 - accuracy: 0.9872 - top-5-accuracy: 1.0000 - val_loss: 0.0251 - val_accuracy: 0.9908 - val_top-5-accuracy: 1.0000
# Epoch 99/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0259 - accuracy: 0.9898 - top-5-accuracy: 1.0000 - val_loss: 0.0466 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 100/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0181 - accuracy: 0.9933 - top-5-accuracy: 1.0000 - val_loss: 0.0201 - val_accuracy: 0.9908 - val_top-5-accuracy: 1.0000
# 21/21 [==============================] - 1s 31ms/step - loss: 0.0348 - accuracy: 0.9893 - top-5-accuracy: 1.0000
# Test accuracy: 98.93%
# Test top 5 accuracy: 100.0%

# %%
plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(vit_history.history['loss'], label='Training Loss')
plt.plot(vit_history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(vit_history.history['accuracy'], label='Training Accuracy')
plt.plot(vit_history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix

vit_predictions = vit_classifier.predict(x_test)
vit_y_pred = np.argmax(vit_predictions, axis=1)  # Convert predicted probabilities to class labels

# Calculate prediction accuracy
accuracy = (vit_y_pred == y_test).mean()
print(f"Prediction Accuracy: {accuracy}")

# Generate the classification report
report = classification_report(y_test, vit_y_pred)
print("Classification Report:")
print(report)

# Generate the confusion matrix
conf_matrix = confusion_matrix(y_test, vit_y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=target_names, yticklabels=target_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 21/21 [==============================] - 1s 28ms/step
# Prediction Accuracy: 0.9892638036809815
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       124
#            1       0.99      0.98      0.99       196
#            2       0.99      0.99      0.99       182
#            3       0.99      1.00      1.00       150
#
#     accuracy                           0.99       652
#    macro avg       0.99      0.99      0.99       652
# weighted avg       0.99      0.99      0.99       652

# %%
from keras.models import save_model

# Assuming you have a trained model called 'model'
#model = create_vit_classifier()  # Replace with your code to create the ViT model
# Train and/or load the weights of the model

# Save the model
#model.save("I:/8th semester/Thesis+Seminar/saved model/vit_model.h5")
#vit_classifier = create_vit_classifier()
# Train and/or load the weights of the model
save_model(vit_classifier,'/kaggle/working/vit.h5')

# %% [markdown]
# CNN****

# %%
class_weights = class_weight.compute_class_weight(class_weight = "balanced", classes= np.unique(y_train), y= y_train)
class_weights = dict(zip(np.unique(y_train), class_weights))
class_weights
# Out:
# {0: 1.701219512195122,
#  1: 0.8261421319796954,
#  2: 0.8432642487046632,
#  3: 0.984375}

# %%
from keras import regularizers
from keras.optimizers import Adam 

model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(filters=32, kernel_size=(3, 3), strides=(1, 1), activation="relu", padding="same", input_shape=(240, 240, 3)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 3), strides=(1, 1), activation="relu", padding="same"),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), activation="relu", padding="same"),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), activation="relu", padding="same"),
    tf.keras.layers.MaxPooling2D((2, 2)),
    #tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), activation="relu", padding="same"),
    #tf.keras.layers.MaxPooling2D((2, 2)),

    tf.keras.layers.Flatten(),

    tf.keras.layers.Dense(units=512, activation='relu',
                          kernel_regularizer=regularizers.L1L2(l1=1e-3, l2=1e-3),
                          bias_regularizer=regularizers.L2(1e-2),
                          activity_regularizer=regularizers.L2(1e-3)),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(units=128, activation='relu',
                          kernel_regularizer=regularizers.L1L2(l1=1e-3, l2=1e-3),
                          bias_regularizer=regularizers.L2(1e-2),
                          activity_regularizer=regularizers.L2(1e-3)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(units=64, activation='relu',
                          kernel_regularizer=regularizers.L1L2(l1=1e-3, l2=1e-3),
                          bias_regularizer=regularizers.L2(1e-2),
                          activity_regularizer=regularizers.L2(1e-3)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(units=32, activation='relu',
                          kernel_regularizer=regularizers.L1L2(l1=1e-3, l2=1e-3),
                          bias_regularizer=regularizers.L2(1e-2),
                          activity_regularizer=regularizers.L2(1e-3)),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(units=4, activation='softmax'),  # 4 classes, so 4 units in the output layer with softmax activation
])

# Compile the model with appropriate loss function and metrics for multiclass classification
model.compile(optimizer=Adam(lr=0.0001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])  # Use 'categorical_crossentropy' if your labels are one-hot encoded
history = model.fit(x_train, y_train, epochs=100, batch_size=32,
                     class_weight=class_weights,validation_data=(x_test, y_test), verbose=1)

test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_accuracy}")
# Out:
# Epoch 1/100
# 62/62 [==============================] - 13s 89ms/step - loss: 116.2002 - accuracy: 0.2652 - val_loss: 74.9200 - val_accuracy: 0.2316
# Epoch 2/100
# 62/62 [==============================] - 4s 72ms/step - loss: 61.2055 - accuracy: 0.2622 - val_loss: 54.3869 - val_accuracy: 0.1902
# Epoch 3/100
# 62/62 [==============================] - 5s 78ms/step - loss: 51.4747 - accuracy: 0.2683 - val_loss: 48.7518 - val_accuracy: 0.3006
# Epoch 4/100
# 62/62 [==============================] - 5s 77ms/step - loss: 46.6218 - accuracy: 0.2586 - val_loss: 44.5229 - val_accuracy: 0.3972
# Epoch 5/100
# 62/62 [==============================] - 5s 76ms/step - loss: 42.8084 - accuracy: 0.2975 - val_loss: 41.0172 - val_accuracy: 0.4755
# Epoch 6/100
# 62/62 [==============================] - 4s 72ms/step - loss: 39.4743 - accuracy: 0.4972 - val_loss: 37.8078 - val_accuracy: 0.5844
# Epoch 7/100
# 62/62 [==============================] - 4s 72ms/step - loss: 36.5010 - accuracy: 0.5955 - val_loss: 34.9675 - val_accuracy: 0.6549
# Epoch 8/100
# 62/62 [==============================] - 4s 72ms/step - loss: 33.8285 - accuracy: 0.6528 - val_loss: 32.4381 - val_accuracy: 0.6840
# Epoch 9/100
# 62/62 [==============================] - 4s 72ms/step - loss: 31.3664 - accuracy: 0.7245 - val_loss: 30.0975 - val_accuracy: 0.7331
# Epoch 10/100
# 62/62 [==============================] - 5s 78ms/step - loss: 29.1293 - accuracy: 0.7486 - val_loss: 27.9095 - val_accuracy: 0.8390
# Epoch 11/100
# 62/62 [==============================] - 5s 76ms/step - loss: 27.0627 - accuracy: 0.7916 - val_loss: 25.9419 - val_accuracy: 0.8635
# Epoch 12/100
# 62/62 [==============================] - 4s 72ms/step - loss: 25.1520 - accuracy: 0.8269 - val_loss: 24.0961 - val_accuracy: 0.8650
# Epoch 13/100
# 62/62 [==============================] - 4s 72ms/step - loss: 23.3971 - accuracy: 0.8571 - val_loss: 22.5801 - val_accuracy: 0.8175
# Epoch 14/100
# 62/62 [==============================] - 5s 76ms/step - loss: 21.8059 - accuracy: 0.8684 - val_loss: 20.9264 - val_accuracy: 0.8972
# Epoch 15/100
# 62/62 [==============================] - 4s 72ms/step - loss: 20.2644 - accuracy: 0.8986 - val_loss: 19.9964 - val_accuracy: 0.6702
# Epoch 16/100
# 62/62 [==============================] - 4s 72ms/step - loss: 18.9008 - accuracy: 0.8976 - val_loss: 18.0620 - val_accuracy: 0.9325
# Epoch 17/100
100
# 62/62 [==============================] - 4s 72ms/step - loss: 1.6581 - accuracy: 0.9944 - val_loss: 1.7105 - val_accuracy: 0.9586
# Epoch 59/100
# 62/62 [==============================] - 5s 73ms/step - loss: 1.6477 - accuracy: 0.9908 - val_loss: 1.6424 - val_accuracy: 0.9647
# Epoch 60/100
# 62/62 [==============================] - 4s 72ms/step - loss: 1.5880 - accuracy: 0.9939 - val_loss: 1.5815 - val_accuracy: 0.9709
# Epoch 61/100
# 62/62 [==============================] - 4s 72ms/step - loss: 1.5210 - accuracy: 0.9959 - val_loss: 1.5417 - val_accuracy: 0.9709
# Epoch 62/100
# 62/62 [==============================] - 5s 76ms/step - loss: 1.4905 - accuracy: 0.9933 - val_loss: 1.5040 - val_accuracy: 0.9678
# Epoch 63/100
# 62/62 [==============================] - 5s 76ms/step - loss: 1.4464 - accuracy: 0.9985 - val_loss: 1.4618 - val_accuracy: 0.9693
# Epoch 64/100
# 62/62 [==============================] - 5s 76ms/step - loss: 1.5084 - accuracy: 0.9785 - val_loss: 1.6086 - val_accuracy: 0.9325
# Epoch 65/100
# 62/62 [==============================] - 5s 77ms/step - loss: 1.5121 - accuracy: 0.9846 - val_loss: 1.5082 - val_accuracy: 0.9678
# Epoch 66/100
# 62/62 [==============================] - 5s 76ms/step - loss: 1.4524 - accuracy: 0.9877 - val_loss: 1.5390 - val_accuracy: 0.9294
# Epoch 67/100
# 62/62 [==============================] - 5s 76ms/step - loss: 1.3776 - accuracy: 0.9933 - val_loss: 1.3766 - val_accuracy: 0.9663
# Epoch 68/100
# 62/62 [==============================] - 5s 76ms/step - loss: 1.3208 - accuracy: 0.9974 - val_loss: 1.3512 - val_accuracy: 0.9632
# Epoch 69/100
# 62/62 [==============================] - 5s 77ms/step - loss: 1.2970 - accuracy: 0.9959 - val_loss: 1.3222 - val_accuracy: 0.9678
# Epoch 70/100
# 62/62 [==============================] - 4s 72ms/step - loss: 1.2719 - accuracy: 0.9980 - val_loss: 1.3193 - val_accuracy: 0.9647
# Epoch 71/100
# 62/62 [==============================] - 5s 76ms/step - loss: 1.2369 - accuracy: 0.9969 - val_loss: 1.2739 - val_accuracy: 0.9709
# Epoch 72/100
# 62/62 [==============================] - 5s 73ms/step - loss: 1.2177 - accuracy: 0.9990 - val_loss: 1.2501 - val_accuracy: 0.9663
# Epoch 73/100
# 62/62 [==============================] - 4s 72ms/step - loss: 1.1963 - accuracy: 0.9974 - val_loss: 1.2363 - val_accuracy: 0.9601
# Epoch 74/100
# 62/62 [==============================] - 5s 76ms/step - loss: 1.1998 - accuracy: 0.9959 - val_loss: 1.2079 - val_accuracy: 0.9693
# Epoch 75/100
# 62/62 [==============================] - 4s 72ms/step - loss: 1.1662 - accuracy: 0.9969 - val_loss: 1.2390 - val_accuracy: 0.9571
# Epoch 76/100
# 62/62 [==============================] - 5s 76ms/step - loss: 1.1793 - accuracy: 0.9969 - val_loss: 1.2578 - val_accuracy: 0.9494
# Epoch 77/100
# 62/62 [==============================] - 4s 72ms/step - loss: 1.1587 - accuracy: 0.9939 - val_loss: 1.1760 - val_accuracy: 0.9739
# Epoch 78/100
# 62/62 [==============================] - 4s 72ms/step - loss: 1.1330 - accuracy: 0.9974 - val_loss: 1.1397 - val_accuracy: 0.9709
# Epoch 79/100
# 62/62 [==============================] - 5s 78ms/step - loss: 1.1068 - accuracy: 0.9964 - val_loss: 1.1597 - val_accuracy: 0.9663
# Epoch 80/100
# 62/62 [==============================] - 5s 76ms/step - loss: 1.1052 - accuracy: 0.9944 - val_loss: 1.1470 - val_accuracy: 0.9555
# Epoch 81/100
# 62/62 [==============================] - 5s 76ms/step - loss: 1.1027 - accuracy: 0.9913 - val_loss: 1.1303 - val_accuracy: 0.9601
# Epoch 82/100
# 62/62 [==============================] - 5s 76ms/step - loss: 1.0605 - accuracy: 0.9969 - val_loss: 1.0857 - val_accuracy: 0.9678
# Epoch 83/100
# 62/62 [==============================] - 4s 72ms/step - loss: 1.0589 - accuracy: 0.9923 - val_loss: 1.2956 - val_accuracy: 0.9095
# Epoch 84/100
# 62/62 [==============================] - 5s 77ms/step - loss: 1.2133 - accuracy: 0.9662 - val_loss: 1.1950 - val_accuracy: 0.9540
# Epoch 85/100
# 62/62 [==============================] - 5s 76ms/step - loss: 1.1445 - accuracy: 0.9811 - val_loss: 1.1251 - val_accuracy: 0.9663
# Epoch 86/100
# 62/62 [==============================] - 5s 73ms/step - loss: 1.0784 - accuracy: 0.9872 - val_loss: 1.0851 - val_accuracy: 0.9617
# Epoch 87/100
# 62/62 [==============================] - 4s 72ms/step - loss: 1.0228 - accuracy: 0.9928 - val_loss: 1.0656 - val_accuracy: 0.9601
# Epoch 88/100
# 62/62 [==============================] - 4s 73ms/step - loss: 0.9850 - accuracy: 0.9964 - val_loss: 1.0158 - val_accuracy: 0.9709
# Epoch 89/100
# 62/62 [==============================] - 5s 77ms/step - loss: 0.9631 - accuracy: 0.9990 - val_loss: 0.9796 - val_accuracy: 0.9739
# Epoch 90/100
# 62/62 [==============================] - 4s 72ms/step - loss: 0.9448 - accuracy: 0.9985 - val_loss: 0.9667 - val_accuracy: 0.9770
# Epoch 91/100
# 62/62 [==============================] - 4s 73ms/step - loss: 0.9315 - accuracy: 0.9980 - val_loss: 0.9663 - val_accuracy: 0.9755
# Epoch 92/100
# 62/62 [==============================] - 5s 77ms/step - loss: 0.9171 - accuracy: 0.9985 - val_loss: 0.9545 - val_accuracy: 0.9739
# Epoch 93/100
# 62/62 [==============================] - 5s 74ms/step - loss: 0.9087 - accuracy: 0.9959 - val_loss: 0.9869 - val_accuracy: 0.9601
# Epoch 94/100
# 62/62 [==============================] - 4s 73ms/step - loss: 0.9078 - accuracy: 0.9964 - val_loss: 0.9442 - val_accuracy: 0.9693
# Epoch 95/100
# 62/62 [==============================] - 4s 73ms/step - loss: 0.8932 - accuracy: 0.9964 - val_loss: 0.9208 - val_accuracy: 0.9693
# Epoch 96/100
# 62/62 [==============================] - 5s 77ms/step - loss: 0.8718 - accuracy: 0.9980 - val_loss: 0.9520 - val_accuracy: 0.9663
# Epoch 97/100
# 62/62 [==============================] - 5s 77ms/step - loss: 0.8905 - accuracy: 0.9923 - val_loss: 0.9371 - val_accuracy: 0.9647
# Epoch 98/100
# 62/62 [==============================] - 5s 76ms/step - loss: 0.8837 - accuracy: 0.9933 - val_loss: 0.9538 - val_accuracy: 0.9571
# Epoch 99/100
# 62/62 [==============================] - 5s 77ms/step - loss: 0.8650 - accuracy: 0.9969 - val_loss: 0.8960 - val_accuracy: 0.9647
# Epoch 100/100
# 62/62 [==============================] - 5s 73ms/step - loss: 0.8371 - accuracy: 0.9980 - val_loss: 0.9148 - val_accuracy: 0.9601
# 21/21 [==============================] - 0s 21ms/step - loss: 0.9148 - accuracy: 0.9601
# Test accuracy: 0.9601227045059204

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_accuracy}")
model.save("/kaggle/working/cnn.h5")
# Out:
# 21/21 [==============================] - 0s 22ms/step - loss: 0.9148 - accuracy: 0.9601
# Test accuracy: 0.9601227045059204

# %%
plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix

# Assuming you have already made predictions and have y_pred and y_test
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
# Convert softmax probabilities to class indices
y_pred_classes = np.argmax(y_pred, axis=1)

# Generate the classification report
target_names = [f"Class {i}" for i in range(4)]  # Replace with actual class names if available
print(classification_report(y_test, y_pred_classes, target_names=target_names))

# Generate the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=target_names, yticklabels=target_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 21/21 [==============================] - 0s 18ms/step
#               precision    recall  f1-score   support
#
#      Class 0       0.94      0.89      0.91       124
#      Class 1       0.96      0.94      0.95       196
#      Class 2       0.96      0.99      0.98       182
#      Class 3       0.97      1.00      0.99       150
#
#     accuracy                           0.96       652
#    macro avg       0.96      0.96      0.96       652
# weighted avg       0.96      0.96      0.96       652

# %%
import tensorflow as tf
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from keras.models import load_model
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# Assuming you have loaded x_test and y_test from your dataset
# x_test should contain the test images and y_test should contain the corresponding labels

# Load the custom objects for the VIT model (if necessary)
custom_objects = {
    "Patches": Patches,
    "PatchEncoder": PatchEncoder,
}

# Load the saved VIT and CNN models
vit_model = tf.keras.models.load_model("/kaggle/working/vit.h5", custom_objects=custom_objects)
cnn_model = tf.keras.models.load_model("/kaggle/working/cnn.h5")

# Make predictions on the test set using both models
vit_predictions = vit_model.predict(x_test)
cnn_predictions = cnn_model.predict(x_test)

# Define the weights for the ensemble (you can adjust these values based on your preference)
vit_weight = 0.6
cnn_weight = 0.4

# Combine the predictions using the weighted ensemble
ensemble_predictions = vit_weight * vit_predictions + cnn_weight * cnn_predictions

# Get the class indices with the highest probability for each sample
ensemble_pred_classes = np.argmax(ensemble_predictions, axis=1)

# Evaluate the ensemble's performance on the test set
ensemble_accuracy = accuracy_score(y_test, ensemble_pred_classes)
print(f"Ensemble Accuracy: {ensemble_accuracy}")

# Generate the classification report for the ensemble
target_names = [f"Class {i}" for i in range(4)]  # Replace with actual class names if available
print("Classification Report:")
print(classification_report(y_test, ensemble_pred_classes, target_names=target_names))

# Generate the confusion matrix for the ensemble
conf_matrix = confusion_matrix(y_test, ensemble_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=target_names, yticklabels=target_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Ensemble Confusion Matrix')
plt.show()
# Out:
# 21/21 [==============================] - 2s 29ms/step
# 21/21 [==============================] - 0s 15ms/step
# Ensemble Accuracy: 0.9892638036809815
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       0.97      0.98      0.98       124
#      Class 1       0.99      0.98      0.99       196
#      Class 2       0.99      0.99      0.99       182
#      Class 3       0.99      1.00      1.00       150
#
#     accuracy                           0.99       652
#    macro avg       0.99      0.99      0.99       652
# weighted avg       0.99      0.99      0.99       652

# %%
visualkeras.layered_view(model, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=1167x1316>
