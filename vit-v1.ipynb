# %%
# !pip install visualkeras
import os
import warnings
import itertools
import cv2
import seaborn as sns
import pandas as pd
import numpy  as np
from PIL import Image
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from collections import Counter

import tensorflow as tf
import tensorflow_addons as tfa
import visualkeras
import plotly.express as px
import matplotlib.pyplot as plt
from sklearn.metrics import multilabel_confusion_matrix
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import plot_model
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from sklearn.model_selection   import train_test_split
from keras.preprocessing.image import ImageDataGenerator

warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from visualkeras) (9.5.0)
# Requirement already satisfied: numpy>=1.18.1 in /opt/conda/lib/python3.10/site-packages (from visualkeras) (1.23.5)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.16-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.0/993.0 kB 16.3 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.16 visualkeras-0.0.2
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
folder_path = "../input/leukemia/Original"
Benign = os.listdir(folder_path + '/Benign/')
Early = os.listdir(folder_path + '/Early/')
Pre = os.listdir(folder_path + '/Pre/')
Pro = os.listdir(folder_path + '/Pro/')
dataset=[]
lab=[]

for image_name in Benign:
    image=cv2.imread(folder_path + '/Benign/' + image_name)
    image=Image.fromarray(image,'RGB')
    image=image.resize((240,240))
    dataset.append(np.array(image))
    lab.append(0)
    
for image_name in Early:
    image=cv2.imread(folder_path + '/Early/' + image_name)
    image=Image.fromarray(image,'RGB')
    image=image.resize((240,240))
    dataset.append(np.array(image))
    lab.append(1)
for image_name in Pre:
    image=cv2.imread(folder_path + '/Pre/' + image_name)
    image=Image.fromarray(image,'RGB')
    image=image.resize((240,240))
    dataset.append(np.array(image))
    lab.append(2)
for image_name in Pro:
    image=cv2.imread(folder_path + '/Pro/' + image_name)
    image=Image.fromarray(image,'RGB')
    image=image.resize((240,240))
    dataset.append(np.array(image))
    lab.append(3)

# %%
dataset = np.array(dataset)
lab = np.array(lab)
print(dataset.shape, lab.shape)
# Out:
# (3256, 240, 240, 3) (3256,)

# %%
from sklearn.model_selection import train_test_split
# !pip install split_folders
import splitfolders
import os
import shutil
from PIL import Image


# Set the random state value
random_state = 42

# Split the data into train, validation, and test sets using arrays
x_train_val, x_test, y_train_val, y_test = train_test_split(dataset, lab, test_size=0.2, shuffle=True, random_state=random_state)
x_train, x_val, y_train, y_val = train_test_split(x_train_val, y_train_val, test_size=0.25, shuffle=True, random_state=random_state)
print(f"train shape: {x_train.shape}- y_train shape: {y_train.shape}")
print(f"test shape: {x_test.shape}- y_test shape: {y_test.shape}")
# Out:
# Requirement already satisfied: split_folders in /opt/conda/lib/python3.10/site-packages (0.5.1)
# train shape: (1953, 240, 240, 3)- y_train shape: (1953,)
# test shape: (652, 240, 240, 3)- y_test shape: (652,)

# %%
epochs = 50
pic_size = 240
np.random.seed(42)
tf.random.set_seed(42)
def plot_state(state):
    plt.figure(figsize= (12,12))
    for i in range(1, 5, 1):
        plt.subplot(3,3,i)
        img = load_img(folder_path + "/" + state + "/" + os.listdir(folder_path + "/" + state)[i], target_size=(pic_size, pic_size))
        plt.imshow(img)   
    plt.show()
plot_state('Early')

# %%
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 32
num_epochs = 100
image_size = 240  # We'll resize input images to this size
patch_size = 20  # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 8
mlp_head_units = [2048, 1024]  # Size of the dense layers of the final classifier

# %%
import tensorflow as tf
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import numpy as np

class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# %%
plt.figure(figsize=(8, 8))
image = x_train[np.random.choice(range(x_train.shape[0]))]
plt.imshow(image.astype("uint8"))

resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(8, 8))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype("uint8"))
    plt.axis("off")
# Out:
# Image size: 240 X 240
# Patch size: 20 X 20
# Patches per image: 144
# Elements per patch: 1200

# %%
data_augmentation = tf.keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
class PatchEncoder(tf.keras.layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
def create_vit_classifier():
    inputs = layers.Input(shape=(240, 240, 3))
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.2
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(4)(features)
    # Create the Keras model.
    model = tf.keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
import tensorflow as tf
import tensorflow_addons as tfa
from keras.models import save_model
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
        metrics=[
            tf.keras.metrics.CategoricalAccuracy(name="accuracy"),
            tf.keras.metrics.TopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    checkpoint_filepath = "/tmp/checkpoint"
    checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        x=x_train,
        y=tf.keras.utils.to_categorical(y_train, num_classes=4),
        batch_size=batch_size,
        epochs=num_epochs,
        validation_data=(x_val, tf.keras.utils.to_categorical(y_val, num_classes=4)),
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(x_test, tf.keras.utils.to_categorical(y_test, num_classes=4))
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    # Save the model
    #model.save("I:/8th semester/Thesis+Seminar/saved model/vit_model.h5")
    #print("ViT model saved successfully!")

    return history

vit_classifier = create_vit_classifier()
vit_history = run_experiment(vit_classifier)
# Out:
# Epoch 1/100
# 62/62 [==============================] - 23s 126ms/step - loss: 2.1995 - accuracy: 0.6656 - top-5-accuracy: 1.0000 - val_loss: 0.6798 - val_accuracy: 0.8264 - val_top-5-accuracy: 1.0000
# Epoch 2/100
# 62/62 [==============================] - 7s 108ms/step - loss: 0.9424 - accuracy: 0.7527 - top-5-accuracy: 1.0000 - val_loss: 0.3704 - val_accuracy: 0.8940 - val_top-5-accuracy: 1.0000
# Epoch 3/100
# 62/62 [==============================] - 7s 119ms/step - loss: 0.4681 - accuracy: 0.8658 - top-5-accuracy: 1.0000 - val_loss: 0.2565 - val_accuracy: 0.9155 - val_top-5-accuracy: 1.0000
# Epoch 4/100
# 62/62 [==============================] - 6s 102ms/step - loss: 0.4157 - accuracy: 0.8848 - top-5-accuracy: 1.0000 - val_loss: 0.2339 - val_accuracy: 0.9293 - val_top-5-accuracy: 1.0000
# Epoch 5/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.2842 - accuracy: 0.9227 - top-5-accuracy: 1.0000 - val_loss: 0.2586 - val_accuracy: 0.9171 - val_top-5-accuracy: 1.0000
# Epoch 6/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.3117 - accuracy: 0.9196 - top-5-accuracy: 1.0000 - val_loss: 0.3412 - val_accuracy: 0.9017 - val_top-5-accuracy: 1.0000
# Epoch 7/100
# 62/62 [==============================] - 6s 102ms/step - loss: 0.2281 - accuracy: 0.9319 - top-5-accuracy: 1.0000 - val_loss: 0.1198 - val_accuracy: 0.9478 - val_top-5-accuracy: 1.0000
# Epoch 8/100
# 62/62 [==============================] - 6s 104ms/step - loss: 0.1640 - accuracy: 0.9452 - top-5-accuracy: 1.0000 - val_loss: 0.1245 - val_accuracy: 0.9647 - val_top-5-accuracy: 1.0000
# Epoch 9/100
# 62/62 [==============================] - 7s 109ms/step - loss: 0.2430 - accuracy: 0.9396 - top-5-accuracy: 1.0000 - val_loss: 0.0784 - val_accuracy: 0.9754 - val_top-5-accuracy: 1.0000
# Epoch 10/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.1345 - accuracy: 0.9570 - top-5-accuracy: 1.0000 - val_loss: 0.1061 - val_accuracy: 0.9739 - val_top-5-accuracy: 1.0000
# Epoch 11/100
# 62/62 [==============================] - 5s 82ms/step - loss: 0.1237 - accuracy: 0.9636 - top-5-accuracy: 1.0000 - val_loss: 0.1100 - val_accuracy: 0.9708 - val_top-5-accuracy: 1.0000
# Epoch 12/100
# 62/62 [==============================] - 6s 102ms/step - loss: 0.1457 - accuracy: 0.9565 - top-5-accuracy: 1.0000 - val_loss: 0.0479 - val_accuracy: 0.9892 - val_top-5-accuracy: 1.0000
# Epoch 13/100
# 62/62 [==============================] - 5s 82ms/step - loss: 0.1560 - accuracy: 0.9549 - top-5-accuracy: 1.0000 - val_loss: 0.1098 - val_accuracy: 0.9708 - val_top-5-accuracy: 1.0000
# Epoch 14/100
# 62/62 [==============================] - 6s 94ms/step - loss: 0.1335 - accuracy: 0.9636 - top-5-accuracy: 1.0000 - val_loss: 0.0508 - val_accuracy: 0.9754 - val_top-5-accuracy: 1.0000
# Epoch 15/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.1417 - accuracy: 0.9667 - top-5-accuracy: 1.0000 - val_loss: 0.0625 - val_accuracy: 0.9770 - val_top-5-accuracy: 1.0000
# Epoch 16/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.0981 - accuracy: 0.9739 - top-5-accuracy: 1.0000 - val_loss: 0.0441 - val_accuracy: 0.9816 - val_top-5-accuracy: 1.0000
# Epoch 17/100
# 62/62 [==============================] - 5s 82ms/step - loss: 0.0938 - accuracy: 0.9739 - top-5-accuracy: 1.0000 - val_loss: 0.1180 - val_accuracy: 0.9677 - val_top-5-accuracy: 1.0000
# Epoch 18/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.1415 - accuracy: 0.9636 - top-5-accuracy: 1.0000 - val_loss: 0.0539 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 19/100
# 62/62 [==============================] - 5s 82ms/step - loss: 0.0641 - accuracy: 0.9759 - top-5-accuracy: 1.0000 - val_loss: 0.0646 - val_accuracy: 0.9800 - val_top-5-accuracy: 1.0000
# Epoch 20/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.1036 - accuracy: 0.9672 - top-5-accuracy: 1.0000 - val_loss: 0.0908 - val_accuracy: 0.9724 - val_top-5-accuracy: 1.0000
# Epoch 21/100
# 62/62 [==============================] - 5s 85ms/step - loss: 0.1128 - accuracy: 0.9713 - top-5-accuracy: 1.0000 - val_loss: 0.0427 - val_accuracy: 0.9892 - val_top-5-accuracy: 1.0000
# Epoch 22/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0898 - accuracy: 0.9749 - top-5-accuracy: 1.0000 - val_loss: 0.0753 - val_accuracy: 0.9770 - val_top-5-accuracy: 1.0000
# Epoch 23/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.1611 - accuracy: 0.9565 - top-5-accuracy: 1.0000 - val_loss: 0.2397 - val_accuracy: 0.9232 - val_top-5-accuracy: 1.0000
# Epoch 24/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.1993 - accuracy: 0.9508 - top-5-accuracy: 1.0000 - val_loss: 0.1125 - val_accuracy: 0.9539 - val_top-5-accuracy: 1.0000
# Epoch 25/100
# 62/62 [==============================] - 5s 82ms/step - loss: 0.1021 - accuracy: 0.9739 - top-5-accuracy: 1.0000 - val_loss: 0.0713 - val_accuracy: 0.9800 - val_top-5-accuracy: 1.0000
# Epoch 26/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.1238 - accuracy: 0.9677 - top-5-accuracy: 1.0000 - val_loss: 0.0560 - val_accuracy: 0.9831 - val_top-5-accuracy: 1.0000
# Epoch 27/100
# 62/62 [==============================] - 5s 85ms/step - loss: 0.0799 - accuracy: 0.9785 - top-5-accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 0.9892 - val_top-5-accuracy: 1.0000
# Epoch 28/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0580 - accuracy: 0.9821 - top-5-accuracy: 1.0000 - val_loss: 0.0476 - val_accuracy: 0.9816 - val_top-5-accuracy: 1.0000
# Epoch 29/100
# 62/62 [==============================] - 6s 104ms/step - loss: 0.0646 - accuracy: 0.9857 - top-5-accuracy: 1.0000 - val_loss: 0.0250 - val_accuracy: 0.9908 - val_top-5-accuracy: 1.0000
# Epoch 30/100
# 62/62 [==============================] - 6s 103ms/step - loss: 0.0496 - accuracy: 0.9805 - top-5-accuracy: 1.0000 - val_loss: 0.0181 - val_accuracy: 0.9954 - val_top-5-accuracy: 1.0000
# Epoch 31/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.0618 - accuracy: 0.9795 - top-5-accuracy: 1.0000 - val_loss: 0.0934 - val_accuracy: 0.9739 - val_top-5-accuracy: 1.0000
# Epoch 32/100
# 62/62 [==============================] - 5s 82ms/step - loss: 0.1368 - accuracy: 0.9724 - top-5-accuracy: 1.0000 - val_loss: 0.0894 - val_accuracy: 0.9816 - val_top-5-accuracy: 1.0000
# Epoch 33/100
# 62/62 [==============================] - 5s 85ms/step - loss: 0.1180 - accuracy: 0.9713 - top-5-accuracy: 1.0000 - val_loss: 0.0768 - val_accuracy: 0.9800 - val_top-5-accuracy: 1.0000
# Epoch 34/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.1529 - accuracy: 0.9611 - top-5-accuracy: 1.0000 - val_loss: 0.0960 - val_accuracy: 0.9785 - val_top-5-accuracy: 1.0000
# Epoch 35/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.1079 - accuracy: 0.9718 - top-5-accuracy: 1.0000 - val_loss: 0.0634 - val_accuracy: 0.9785 - val_top-5-accuracy: 1.0000
# Epoch 36/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.0805 - accuracy: 0.9795 - top-5-accuracy: 1.0000 - val_loss: 0.0575 - val_accuracy: 0.9800 - val_top-5-accuracy: 1.0000
# Epoch 37/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.1708 - accuracy: 0.9585 - top-5-accuracy: 1.0000 - val_loss: 0.0576 - val_accuracy: 0.9846 - val_top-5-accuracy: 1.0000
# Epoch 38/100
# 62/62 [==============================] - 5s 82ms/step - loss: 0.0735 - accuracy: 0.9811 - top-5-accuracy: 1.0000 - val_loss: 0.0500 - val_accuracy: 0.9892 - val_top-5-accuracy: 1.0000
# Epoch 39/100
# 62/62 [==============================] - 5s 86ms/step - loss: 0.0843 - accuracy: 0.9790 - top-5-accuracy: 1.0000 - val_loss: 0.1403 - val_accuracy: 0.9616 - val_top-5-accuracy: 1.0000
# Epoch 40/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.0749 - accuracy: 0.9770 - top-5-accuracy: 1.0000 - val_loss: 0.1004 - val_accuracy: 0.9708 - val_top-5-accuracy: 1.0000
# Epoch 41/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0883 - accuracy: 0.9800 - top-5-accuracy: 1.0000 - val_loss: 0.1253 - val_accuracy: 0.9708 - val_top-5-accuracy: 1.0000
# Epoch 42/100
# 62/62 [==============================] - 5s 82ms/step - loss: 0.0843 - accuracy: 0.9759 - top-5-accuracy: 1.0000 - val_loss: 0.0488 - val_accuracy: 0.9923 - val_top-5-accuracy: 1.0000
# Epoch 43/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.0636 - accuracy: 0.9821 - top-5-accuracy: 1.0000 - val_loss: 0.0273 - val_accuracy: 0.9954 - val_top-5-accuracy: 1.0000
# Epoch 44/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.0759 - accuracy: 0.9811 - top-5-accuracy: 1.0000 - val_loss: 0.0423 - val_accuracy: 0.9862 - val_top-5-accuracy: 1.0000
# Epoch 45/100
# 62/62 [==============================] - 5s 84ms/step - loss: 0.0468 - accuracy: 0.9826 - top-5-accuracy: 1.0000 - val_loss: 0.0738 - val_accuracy: 0.9770 - val_top-5-accuracy: 1.0000
# Epoch 46/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.1891 - accuracy: 0.9544 - top-5-accuracy: 1.0000 - val_loss: 0.1241 - val_accuracy: 0.9785 - val_top-5-accuracy: 1.0000
# Epoch 47/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.1329 - accuracy: 0.9708 - top-5-accuracy: 1.0000 - val_loss: 0.0831 - val_accuracy: 0.9785 - val_top-5-accuracy: 1.0000
# Epoch 48/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.0632 - accuracy: 0.9795 - top-5-accuracy: 1.0000 - val_loss: 0.0870 - val_accuracy: 0.9724 - val_top-5-accuracy: 1.0000
# Epoch 49/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.0632 - accuracy: 0.9846 - top-5-accuracy: 1.0000 - val_loss: 0.0509 - val_accuracy: 0.9816 - val_top-5-accuracy: 1.0000
# Epoch 50/100
# 62/62 [==============================] - 5s 82ms/step - loss: 0.0302 - accuracy: 0.9913 - top-5-accuracy: 1.0000 - val_loss: 0.0632 - val_accuracy: 0.9800 - val_top-5-accuracy: 1.0000
# Epoch 51/100
# 62/62 [==============================] - 5s 83ms/step - loss: 0.0523 - accuracy: 0.9826 - top-5-accuracy: 1.0000 - val_loss: 0.0401 - val_accuracy: 0.9800 - val_top-5-accuracy: 1.0000
# Epoch 52/100
# 62/62 [==============================] - 5s 84ms/step - loss: 0.0327 - accuracy: 0.9877 - top-5-accuracy: 1.0000 - val_loss: 0.0644 - val_accuracy: 0.9754 - val_top-5-accuracy: 1.0000
# Epoch 53/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.0382 - accuracy: 0.9877 - top-5-accuracy: 1.0000 - val_loss: 0.0574 - val_accuracy: 0.9831 - val_top-5-accuracy: 1.0000
# Epoch 54/100
# 62/62 [==============================] - 5s 82ms/step - loss: 0.0280 - accuracy: 0.9918 - top-5-accuracy: 1.0000 - val_loss: 0.0800 - val_accuracy: 0.9862 - val_top-5-accuracy: 1.0000
# Epoch 55/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.0742 - accuracy: 0.9816 - top-5-accuracy: 1.0000 - val_loss: 0.0305 - val_accuracy: 0.9862 - val_top-5-accuracy: 1.0000
# Epoch 56/100
# 62/62 [==============================] - 5s 82ms/step - loss: 0.0937 - accuracy: 0.9805 - top-5-accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9846 - val_top-5-accuracy: 1.0000
# Epoch 57/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.2892 - accuracy: 0.9370 - top-5-accuracy: 1.0000 - val_loss: 0.0378 - val_accuracy: 0.9892 - val_top-5-accuracy: 1.0000
# Epoch 58/100
# 62/62 [==============================] - 5s 84ms/step - loss: 0.0827 - accuracy: 0.9775 - top-5-accuracy: 1.0000 - val_loss: 0.0965 - val_accuracy: 0.9693 - val_top-5-accuracy: 1.0000
# Epoch 59/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.0768 - accuracy: 0.9770 - top-5-accuracy: 1.0000 - val_loss: 0.0600 - val_accuracy: 0.9770 - val_top-5-accuracy: 1.0000
# Epoch 60/100
# 62/62 [==============================] - 5s 82ms/step - loss: 0.0738 - accuracy: 0.9821 - top-5-accuracy: 1.0000 - val_loss: 0.0595 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 61/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0715 - accuracy: 0.9836 - top-5-accuracy: 1.0000 - val_loss: 0.0439 - val_accuracy: 0.9892 - val_top-5-accuracy: 1.0000
# Epoch 62/100
# 62/62 [==============================] - 5s 82ms/step - loss: 0.0557 - accuracy: 0.9892 - top-5-accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9923 - val_top-5-accuracy: 1.0000
# Epoch 63/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0414 - accuracy: 0.9872 - top-5-accuracy: 1.0000 - val_loss: 0.0316 - val_accuracy: 0.9862 - val_top-5-accuracy: 1.0000
# Epoch 64/100
# 62/62 [==============================] - 5s 85ms/step - loss: 0.0187 - accuracy: 0.9928 - top-5-accuracy: 1.0000 - val_loss: 0.0563 - val_accuracy: 0.9846 - val_top-5-accuracy: 1.0000
# Epoch 65/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.0612 - accuracy: 0.9857 - top-5-accuracy: 1.0000 - val_loss: 0.0860 - val_accuracy: 0.9816 - val_top-5-accuracy: 1.0000
# Epoch 66/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.0431 - accuracy: 0.9882 - top-5-accuracy: 1.0000 - val_loss: 0.0307 - val_accuracy: 0.9939 - val_top-5-accuracy: 1.0000
# Epoch 67/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.0432 - accuracy: 0.9872 - top-5-accuracy: 1.0000 - val_loss: 0.1195 - val_accuracy: 0.9754 - val_top-5-accuracy: 1.0000
# Epoch 68/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.0440 - accuracy: 0.9872 - top-5-accuracy: 1.0000 - val_loss: 0.0555 - val_accuracy: 0.9862 - val_top-5-accuracy: 1.0000
# Epoch 69/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.0593 - accuracy: 0.9872 - top-5-accuracy: 1.0000 - val_loss: 0.0518 - val_accuracy: 0.9862 - val_top-5-accuracy: 1.0000
# Epoch 70/100
# 62/62 [==============================] - 6s 96ms/step - loss: 0.0206 - accuracy: 0.9928 - top-5-accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9892 - val_top-5-accuracy: 1.0000
# Epoch 71/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.0410 - accuracy: 0.9867 - top-5-accuracy: 1.0000 - val_loss: 0.1007 - val_accuracy: 0.9662 - val_top-5-accuracy: 1.0000
# Epoch 72/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.0430 - accuracy: 0.9908 - top-5-accuracy: 1.0000 - val_loss: 0.0821 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 73/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.0851 - accuracy: 0.9826 - top-5-accuracy: 1.0000 - val_loss: 0.0303 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 74/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.0642 - accuracy: 0.9862 - top-5-accuracy: 1.0000 - val_loss: 0.0266 - val_accuracy: 0.9923 - val_top-5-accuracy: 1.0000
# Epoch 75/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0510 - accuracy: 0.9831 - top-5-accuracy: 1.0000 - val_loss: 0.0688 - val_accuracy: 0.9846 - val_top-5-accuracy: 1.0000
# Epoch 76/100
# 62/62 [==============================] - 6s 93ms/step - loss: 0.0187 - accuracy: 0.9949 - top-5-accuracy: 1.0000 - val_loss: 0.0382 - val_accuracy: 0.9892 - val_top-5-accuracy: 1.0000
# Epoch 77/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.0100 - accuracy: 0.9954 - top-5-accuracy: 1.0000 - val_loss: 0.0309 - val_accuracy: 0.9892 - val_top-5-accuracy: 1.0000
# Epoch 78/100
# 62/62 [==============================] - 5s 82ms/step - loss: 0.0110 - accuracy: 0.9954 - top-5-accuracy: 1.0000 - val_loss: 0.0258 - val_accuracy: 0.9923 - val_top-5-accuracy: 1.0000
# Epoch 79/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.0205 - accuracy: 0.9954 - top-5-accuracy: 1.0000 - val_loss: 0.0363 - val_accuracy: 0.9892 - val_top-5-accuracy: 1.0000
# Epoch 80/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.0113 - accuracy: 0.9959 - top-5-accuracy: 1.0000 - val_loss: 0.0494 - val_accuracy: 0.9954 - val_top-5-accuracy: 1.0000
# Epoch 81/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.0877 - accuracy: 0.9805 - top-5-accuracy: 1.0000 - val_loss: 0.0537 - val_accuracy: 0.9846 - val_top-5-accuracy: 1.0000
# Epoch 82/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0800 - accuracy: 0.9800 - top-5-accuracy: 1.0000 - val_loss: 0.0972 - val_accuracy: 0.9816 - val_top-5-accuracy: 1.0000
# Epoch 83/100
# 62/62 [==============================] - 6s 95ms/step - loss: 0.0636 - accuracy: 0.9852 - top-5-accuracy: 1.0000 - val_loss: 0.1366 - val_accuracy: 0.9724 - val_top-5-accuracy: 1.0000
# Epoch 84/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.0447 - accuracy: 0.9831 - top-5-accuracy: 1.0000 - val_loss: 0.0575 - val_accuracy: 0.9908 - val_top-5-accuracy: 1.0000
# Epoch 85/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.0660 - accuracy: 0.9826 - top-5-accuracy: 1.0000 - val_loss: 0.0763 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 86/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.0262 - accuracy: 0.9913 - top-5-accuracy: 1.0000 - val_loss: 0.0281 - val_accuracy: 0.9939 - val_top-5-accuracy: 1.0000
# Epoch 87/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.0480 - accuracy: 0.9898 - top-5-accuracy: 1.0000 - val_loss: 0.0330 - val_accuracy: 0.9846 - val_top-5-accuracy: 1.0000
# Epoch 88/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.0525 - accuracy: 0.9862 - top-5-accuracy: 1.0000 - val_loss: 0.0339 - val_accuracy: 0.9831 - val_top-5-accuracy: 1.0000
# Epoch 89/100
# 62/62 [==============================] - 5s 86ms/step - loss: 0.0736 - accuracy: 0.9811 - top-5-accuracy: 1.0000 - val_loss: 0.0562 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 90/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.0786 - accuracy: 0.9800 - top-5-accuracy: 1.0000 - val_loss: 0.0908 - val_accuracy: 0.9862 - val_top-5-accuracy: 1.0000
# Epoch 91/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.0627 - accuracy: 0.9831 - top-5-accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9754 - val_top-5-accuracy: 1.0000
# Epoch 92/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0783 - accuracy: 0.9800 - top-5-accuracy: 1.0000 - val_loss: 0.0910 - val_accuracy: 0.9892 - val_top-5-accuracy: 1.0000
# Epoch 93/100
# 62/62 [==============================] - 5s 82ms/step - loss: 0.0937 - accuracy: 0.9759 - top-5-accuracy: 1.0000 - val_loss: 0.0612 - val_accuracy: 0.9785 - val_top-5-accuracy: 1.0000
# Epoch 94/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.1339 - accuracy: 0.9734 - top-5-accuracy: 1.0000 - val_loss: 0.1535 - val_accuracy: 0.9693 - val_top-5-accuracy: 1.0000
# Epoch 95/100
# 62/62 [==============================] - 5s 87ms/step - loss: 0.1422 - accuracy: 0.9713 - top-5-accuracy: 1.0000 - val_loss: 0.0853 - val_accuracy: 0.9785 - val_top-5-accuracy: 1.0000
# Epoch 96/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0678 - accuracy: 0.9831 - top-5-accuracy: 1.0000 - val_loss: 0.0834 - val_accuracy: 0.9800 - val_top-5-accuracy: 1.0000
# Epoch 97/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0442 - accuracy: 0.9867 - top-5-accuracy: 1.0000 - val_loss: 0.0706 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 98/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0575 - accuracy: 0.9882 - top-5-accuracy: 1.0000 - val_loss: 0.0830 - val_accuracy: 0.9785 - val_top-5-accuracy: 1.0000
# Epoch 99/100
# 62/62 [==============================] - 5s 80ms/step - loss: 0.0500 - accuracy: 0.9862 - top-5-accuracy: 1.0000 - val_loss: 0.0369 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 100/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0402 - accuracy: 0.9903 - top-5-accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# 21/21 [==============================] - 1s 28ms/step - loss: 0.0457 - accuracy: 0.9923 - top-5-accuracy: 1.0000
# Test accuracy: 99.23%
# Test top 5 accuracy: 100.0%

# %%
plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(vit_history.history['loss'], label='Training Loss')
plt.plot(vit_history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(vit_history.history['accuracy'], label='Training Accuracy')
plt.plot(vit_history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report
vit_predictions = vit_classifier.predict(x_test)
vit_y_pred = np.argmax(vit_predictions, axis=1) # Convert predicted probabilities to class labels
#vit_pred = np.argmax(vit_predictions, axis=1)

# Calculate prediction accuracy
accuracy = (vit_y_pred == y_test).mean()
print(f"Prediction Accuracy: {accuracy}")

report = classification_report(y_test,vit_y_pred)

print("Classification Report:")
print(report)
# Out:
# 21/21 [==============================] - 2s 32ms/step
# Prediction Accuracy: 0.9923312883435583
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       124
#            1       0.99      0.99      0.99       196
#            2       0.99      0.99      0.99       182
#            3       0.99      1.00      1.00       150
#
#     accuracy                           0.99       652
#    macro avg       0.99      0.99      0.99       652
# weighted avg       0.99      0.99      0.99       652

# %%
from keras.models import save_model

# Assuming you have a trained model called 'model'
#model = create_vit_classifier()  # Replace with your code to create the ViT model
# Train and/or load the weights of the model

# Save the model
#model.save("I:/8th semester/Thesis+Seminar/saved model/vit_model.h5")
#vit_classifier = create_vit_classifier()
# Train and/or load the weights of the model
save_model(vit_classifier,'/kaggle/working/vit.h5')

# %% [markdown]
# CNN****

# %%
import tensorflow as tf
from tensorflow.keras import layers, regularizers

# Define the CNN model
model = tf.keras.Sequential([
    layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(240, 240, 3)),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Conv2D(filters=128, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Flatten(),
    layers.Dense(units=256, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.5),
    layers.Dense(units=128, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.5),
    layers.Dense(units=4, activation='softmax')  # 4 classes, so 4 units in the output layer with softmax activation
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',  # Use 'categorical_crossentropy' if your labels are one-hot encoded
              metrics=['accuracy'])  # Add other evaluation metrics as needed

# Train the model
history = model.fit(x_train, y_train, epochs=100, batch_size=32, validation_data=(x_val, y_val))

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_accuracy}")
# Out:
# Epoch 1/100
# 62/62 [==============================] - 7s 70ms/step - loss: 33.8134 - accuracy: 0.4977 - val_loss: 7.4209 - val_accuracy: 0.4101
# Epoch 2/100
# 62/62 [==============================] - 4s 65ms/step - loss: 7.1151 - accuracy: 0.4839 - val_loss: 6.4369 - val_accuracy: 0.6651
# Epoch 3/100
# 62/62 [==============================] - 4s 60ms/step - loss: 6.1935 - accuracy: 0.5617 - val_loss: 5.7548 - val_accuracy: 0.5668
# Epoch 4/100
# 62/62 [==============================] - 4s 64ms/step - loss: 5.3395 - accuracy: 0.6641 - val_loss: 5.2237 - val_accuracy: 0.5837
# Epoch 5/100
# 62/62 [==============================] - 4s 59ms/step - loss: 4.8688 - accuracy: 0.7215 - val_loss: 12.5487 - val_accuracy: 0.3103
# Epoch 6/100
# 62/62 [==============================] - 4s 59ms/step - loss: 5.6209 - accuracy: 0.3717 - val_loss: 4.9758 - val_accuracy: 0.4209
# Epoch 7/100
# 62/62 [==============================] - 4s 64ms/step - loss: 4.7775 - accuracy: 0.4050 - val_loss: 4.6715 - val_accuracy: 0.3917
# Epoch 8/100
# 62/62 [==============================] - 4s 59ms/step - loss: 4.4288 - accuracy: 0.4578 - val_loss: 4.2263 - val_accuracy: 0.4562
# Epoch 9/100
# 62/62 [==============================] - 4s 59ms/step - loss: 4.0753 - accuracy: 0.4526 - val_loss: 3.9507 - val_accuracy: 0.4916
# Epoch 10/100
# 62/62 [==============================] - 4s 60ms/step - loss: 3.7890 - accuracy: 0.4895 - val_loss: 3.7135 - val_accuracy: 0.4240
# Epoch 11/100
# 62/62 [==============================] - 4s 64ms/step - loss: 3.5613 - accuracy: 0.5212 - val_loss: 3.5804 - val_accuracy: 0.5161
# Epoch 12/100
# 62/62 [==============================] - 4s 59ms/step - loss: 3.3501 - accuracy: 0.6114 - val_loss: 4.0630 - val_accuracy: 0.2842
# Epoch 13/100
# 62/62 [==============================] - 4s 59ms/step - loss: 3.2117 - accuracy: 0.5719 - val_loss: 4.0995 - val_accuracy: 0.4455
# Epoch 14/100
# 62/62 [==============================] - 4s 59ms/step - loss: 3.3898 - accuracy: 0.5760 - val_loss: 3.3333 - val_accuracy: 0.4777
# Epoch 15/100
# 62/62 [==============================] - 4s 64ms/step - loss: 3.2760 - accuracy: 0.6252 - val_loss: 3.5741 - val_accuracy: 0.5545
# Epoch 16/100
# 62/62 [==============================] - 4s 64ms/step - loss: 2.9930 - accuracy: 0.6656 - val_loss: 3.2086 - val_accuracy: 0.5806
# Epoch 17/100
# 62/62 [==============================] - 4s 59ms/step - loss: 2.9170 - accuracy: 0.6851 - val_loss: 3.1503 - val_accuracy: 0.5453
# Epoch 18/100
# 62/62 [==============================] - 4s 60ms/step - loss: 3.0954 - accuracy: 0.7066 - val_loss: 3.1670 - val_accuracy: 0.6636
# Epoch 19/100
# 62/62 [==============================] - 4s 59ms/step - loss: 2.9162 - accuracy: 0.7686 - val_loss: 2.9791 - val_accuracy: 0.6989
# Epoch 20/100
# 62/62 [==============================] - 4s 64ms/step - loss: 2.5455 - accuracy: 0.8233 - val_loss: 2.9954 - val_accuracy: 0.6037
# Epoch 21/100
# 62/62 [==============================] - 4s 64ms/step - loss: 3.4087 - accuracy: 0.6697 - val_loss: 3.4333 - val_accuracy: 0.5945
# Epoch 22/100
# 62/62 [==============================] - 4s 59ms/step - loss: 3.1976 - accuracy: 0.7143 - val_loss: 3.1424 - val_accuracy: 0.6651
# Epoch 23/100
# 62/62 [==============================] - 4s 64ms/step - loss: 2.6108 - accuracy: 0.7588 - val_loss: 2.7492 - val_accuracy: 0.6544
# Epoch 24/100
# 62/62 [==============================] - 4s 59ms/step - loss: 2.3166 - accuracy: 0.7742 - val_loss: 2.5736 - val_accuracy: 0.6513
# Epoch 25/100
# 62/62 [==============================] - 4s 64ms/step - loss: 2.0848 - accuracy: 0.8136 - val_loss: 2.5000 - val_accuracy: 0.7020
# Epoch 26/100
# 62/62 [==============================] - 4s 64ms/step - loss: 1.9541 - accuracy: 0.8382 - val_loss: 2.6490 - val_accuracy: 0.6636
# Epoch 27/100
# 62/62 [==============================] - 4s 60ms/step - loss: 1.9164 - accuracy: 0.8438 - val_loss: 2.1030 - val_accuracy: 0.7696
# Epoch 28/100
# 62/62 [==============================] - 4s 59ms/step - loss: 1.7115 - accuracy: 0.9002 - val_loss: 1.9470 - val_accuracy: 0.8111
# Epoch 29/100
# 62/62 [==============================] - 4s 64ms/step - loss: 1.5728 - accuracy: 0.9227 - val_loss: 1.9048 - val_accuracy: 0.7896
# Epoch 30/100
# 62/62 [==============================] - 4s 59ms/step - loss: 1.5295 - accuracy: 0.9206 - val_loss: 1.9331 - val_accuracy: 0.7634
# Epoch 31/100
# 62/62 [==============================] - 4s 64ms/step - loss: 1.4915 - accuracy: 0.9206 - val_loss: 1.8417 - val_accuracy: 0.7957
# Epoch 32/100
# 62/62 [==============================] - 4s 59ms/step - loss: 1.4464 - accuracy: 0.9252 - val_loss: 1.8859 - val_accuracy: 0.7711
# Epoch 33/100
# 62/62 [==============================] - 4s 64ms/step - loss: 5.6070 - accuracy: 0.6621 - val_loss: 5.5536 - val_accuracy: 0.7619
# Epoch 34/100
# 62/62 [==============================] - 4s 63ms/step - loss: 4.1472 - accuracy: 0.8730 - val_loss: 3.4574 - val_accuracy: 0.8203
# Epoch 35/100
# 62/62 [==============================] - 4s 61ms/step - loss: 2.8232 - accuracy: 0.9094 - val_loss: 2.7244 - val_accuracy: 0.8126
# Epoch 36/100
# 62/62 [==============================] - 4s 59ms/step - loss: 2.6071 - accuracy: 0.8950 - val_loss: 3.4743 - val_accuracy: 0.8233
# Epoch 37/100
# 62/62 [==============================] - 4s 64ms/step - loss: 3.1075 - accuracy: 0.9406 - val_loss: 2.8599 - val_accuracy: 0.7942
# Epoch 38/100
# 62/62 [==============================] - 4s 64ms/step - loss: 2.2338 - accuracy: 0.9421 - val_loss: 2.2500 - val_accuracy: 0.8065
# Epoch 39/100
# 62/62 [==============================] - 4s 63ms/step - loss: 1.7512 - accuracy: 0.9544 - val_loss: 1.9695 - val_accuracy: 0.8587
# Epoch 40/100
# 62/62 [==============================] - 4s 59ms/step - loss: 1.5797 - accuracy: 0.9483 - val_loss: 1.7650 - val_accuracy: 0.8602
# Epoch 41/100
# 62/62 [==============================] - 4s 59ms/step - loss: 1.4246 - accuracy: 0.9544 - val_loss: 1.6613 - val_accuracy: 0.8771
# Epoch 42/100
# 62/62 [==============================] - 4s 64ms/step - loss: 1.3479 - accuracy: 0.9483 - val_loss: 1.6278 - val_accuracy: 0.8679
# Epoch 43/100
# 62/62 [==============================] - 4s 65ms/step - loss: 1.2580 - accuracy: 0.9601 - val_loss: 1.5281 - val_accuracy: 0.8449
# Epoch 44/100
# 62/62 [==============================] - 4s 64ms/step - loss: 1.1315 - accuracy: 0.9672 - val_loss: 1.3788 - val_accuracy: 0.8817
# Epoch 45/100
# 62/62 [==============================] - 4s 59ms/step - loss: 1.0511 - accuracy: 0.9759 - val_loss: 1.3729 - val_accuracy: 0.8756
# Epoch 46/100
# 62/62 [==============================] - 4s 63ms/step - loss: 1.0389 - accuracy: 0.9698 - val_loss: 1.5199 - val_accuracy: 0.8740
# Epoch 47/100
# 62/62 [==============================] - 4s 63ms/step - loss: 1.0789 - accuracy: 0.9427 - val_loss: 1.4155 - val_accuracy: 0.8602
# Epoch 48/100
# 62/62 [==============================] - 4s 63ms/step - loss: 0.9888 - accuracy: 0.9744 - val_loss: 1.3657 - val_accuracy: 0.8925
# Epoch 49/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.9339 - accuracy: 0.9764 - val_loss: 1.3032 - val_accuracy: 0.8940
# Epoch 50/100
# 62/62 [==============================] - 4s 64ms/step - loss: 1.5022 - accuracy: 0.8479 - val_loss: 2.8216 - val_accuracy: 0.7542
# Epoch 51/100
# 62/62 [==============================] - 4s 61ms/step - loss: 2.3159 - accuracy: 0.8699 - val_loss: 1.9425 - val_accuracy: 0.8356
# Epoch 52/100
# 62/62 [==============================] - 4s 59ms/step - loss: 1.5602 - accuracy: 0.9304 - val_loss: 1.6812 - val_accuracy: 0.8710
# Epoch 53/100
# 62/62 [==============================] - 4s 59ms/step - loss: 1.1871 - accuracy: 0.9667 - val_loss: 1.4479 - val_accuracy: 0.8464
# Epoch 54/100
# 62/62 [==============================] - 4s 64ms/step - loss: 1.1508 - accuracy: 0.9519 - val_loss: 1.4826 - val_accuracy: 0.8955
# Epoch 55/100
# 62/62 [==============================] - 4s 64ms/step - loss: 1.0607 - accuracy: 0.9601 - val_loss: 1.2926 - val_accuracy: 0.8802
# Epoch 56/100
# 62/62 [==============================] - 4s 64ms/step - loss: 0.8974 - accuracy: 0.9764 - val_loss: 1.2315 - val_accuracy: 0.8909
# Epoch 57/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.8201 - accuracy: 0.9764 - val_loss: 1.1802 - val_accuracy: 0.8725
# Epoch 58/100
# 62/62 [==============================] - 4s 64ms/step - loss: 0.9791 - accuracy: 0.9437 - val_loss: 1.3170 - val_accuracy: 0.8587
# Epoch 59/100
# 62/62 [==============================] - 4s 61ms/step - loss: 1.0063 - accuracy: 0.9565 - val_loss: 1.2350 - val_accuracy: 0.8955
# Epoch 60/100
# 62/62 [==============================] - 4s 64ms/step - loss: 0.8952 - accuracy: 0.9764 - val_loss: 1.2037 - val_accuracy: 0.8694
# Epoch 61/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.8399 - accuracy: 0.9729 - val_loss: 1.1320 - val_accuracy: 0.8802
# Epoch 62/100
# 62/62 [==============================] - 4s 64ms/step - loss: 0.7524 - accuracy: 0.9816 - val_loss: 1.0834 - val_accuracy: 0.8955
# Epoch 63/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.7169 - accuracy: 0.9862 - val_loss: 1.2348 - val_accuracy: 0.8571
# Epoch 64/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.9424 - accuracy: 0.9350 - val_loss: 1.2525 - val_accuracy: 0.8802
# Epoch 65/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.9026 - accuracy: 0.9621 - val_loss: 1.0894 - val_accuracy: 0.8710
# Epoch 66/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.8105 - accuracy: 0.9677 - val_loss: 1.1381 - val_accuracy: 0.8694
# Epoch 67/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.7523 - accuracy: 0.9775 - val_loss: 1.0331 - val_accuracy: 0.8909
# Epoch 68/100
# 62/62 [==============================] - 4s 60ms/step - loss: 0.7774 - accuracy: 0.9616 - val_loss: 1.1545 - val_accuracy: 0.8786
# Epoch 69/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.8203 - accuracy: 0.9677 - val_loss: 1.0275 - val_accuracy: 0.8817
# Epoch 70/100
# 62/62 [==============================] - 4s 64ms/step - loss: 0.7624 - accuracy: 0.9657 - val_loss: 1.1265 - val_accuracy: 0.8618
# Epoch 71/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.8081 - accuracy: 0.9616 - val_loss: 1.0904 - val_accuracy: 0.8940
# Epoch 72/100
# 62/62 [==============================] - 4s 64ms/step - loss: 0.8894 - accuracy: 0.9565 - val_loss: 1.1307 - val_accuracy: 0.9063
# Epoch 73/100
# 62/62 [==============================] - 4s 64ms/step - loss: 0.9492 - accuracy: 0.9457 - val_loss: 1.3263 - val_accuracy: 0.8233
# Epoch 74/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.9269 - accuracy: 0.9652 - val_loss: 1.1090 - val_accuracy: 0.8986
# Epoch 75/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.7545 - accuracy: 0.9846 - val_loss: 1.1108 - val_accuracy: 0.8925
# Epoch 76/100
# 62/62 [==============================] - 4s 61ms/step - loss: 0.7042 - accuracy: 0.9770 - val_loss: 1.2139 - val_accuracy: 0.8402
# Epoch 77/100
# 62/62 [==============================] - 4s 64ms/step - loss: 0.7801 - accuracy: 0.9616 - val_loss: 1.0840 - val_accuracy: 0.8955
# Epoch 78/100
# 62/62 [==============================] - 4s 64ms/step - loss: 0.7174 - accuracy: 0.9821 - val_loss: 0.9925 - val_accuracy: 0.8879
# Epoch 79/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.6254 - accuracy: 0.9857 - val_loss: 0.9397 - val_accuracy: 0.8940
# Epoch 80/100
# 62/62 [==============================] - 4s 64ms/step - loss: 0.5769 - accuracy: 0.9816 - val_loss: 0.9232 - val_accuracy: 0.8848
# Epoch 81/100
# 62/62 [==============================] - 4s 64ms/step - loss: 0.6761 - accuracy: 0.9764 - val_loss: 0.9828 - val_accuracy: 0.8894
# Epoch 82/100
# 62/62 [==============================] - 4s 64ms/step - loss: 0.6546 - accuracy: 0.9770 - val_loss: 0.9580 - val_accuracy: 0.8940
# Epoch 83/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.6443 - accuracy: 0.9749 - val_loss: 1.1399 - val_accuracy: 0.8034
# Epoch 84/100
# 62/62 [==============================] - 4s 64ms/step - loss: 0.8568 - accuracy: 0.9555 - val_loss: 1.1017 - val_accuracy: 0.8971
# Epoch 85/100
# 62/62 [==============================] - 4s 64ms/step - loss: 0.7161 - accuracy: 0.9790 - val_loss: 0.9555 - val_accuracy: 0.9017
# Epoch 86/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.6414 - accuracy: 0.9775 - val_loss: 0.9873 - val_accuracy: 0.9017
# Epoch 87/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.7298 - accuracy: 0.9672 - val_loss: 1.0634 - val_accuracy: 0.8940
# Epoch 88/100
# 62/62 [==============================] - 4s 64ms/step - loss: 0.7219 - accuracy: 0.9795 - val_loss: 0.9717 - val_accuracy: 0.9155
# Epoch 89/100
# 62/62 [==============================] - 4s 64ms/step - loss: 0.5444 - accuracy: 0.9939 - val_loss: 0.8520 - val_accuracy: 0.8909
# Epoch 90/100
# 62/62 [==============================] - 4s 64ms/step - loss: 0.5633 - accuracy: 0.9780 - val_loss: 0.9324 - val_accuracy: 0.9048
# Epoch 91/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.5324 - accuracy: 0.9852 - val_loss: 0.8163 - val_accuracy: 0.8955
# Epoch 92/100
# 62/62 [==============================] - 4s 64ms/step - loss: 0.5767 - accuracy: 0.9749 - val_loss: 0.8445 - val_accuracy: 0.8940
# Epoch 93/100
# 62/62 [==============================] - 4s 64ms/step - loss: 0.6196 - accuracy: 0.9754 - val_loss: 0.9835 - val_accuracy: 0.9032
# Epoch 94/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.5819 - accuracy: 0.9831 - val_loss: 0.9191 - val_accuracy: 0.9078
# Epoch 95/100
# 62/62 [==============================] - 4s 64ms/step - loss: 0.5882 - accuracy: 0.9770 - val_loss: 0.9086 - val_accuracy: 0.9032
# Epoch 96/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.6390 - accuracy: 0.9739 - val_loss: 0.9506 - val_accuracy: 0.8955
# Epoch 97/100
# 62/62 [==============================] - 4s 64ms/step - loss: 0.6118 - accuracy: 0.9826 - val_loss: 0.9782 - val_accuracy: 0.8633
# Epoch 98/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.6552 - accuracy: 0.9657 - val_loss: 1.1377 - val_accuracy: 0.8602
# Epoch 99/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.8376 - accuracy: 0.9570 - val_loss: 0.9885 - val_accuracy: 0.9078
# Epoch 100/100
# 62/62 [==============================] - 4s 64ms/step - loss: 0.5873 - accuracy: 0.9918 - val_loss: 0.9292 - val_accuracy: 0.9109
# 21/21 [==============================] - 0s 18ms/step - loss: 1.0753 - accuracy: 0.8788
# Test accuracy: 0.8788343667984009

# %%
plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
model.save("/kaggle/working/cnn1.h5")

# %%
import numpy as np
from sklearn.metrics import classification_report

# Make predictions on the test set
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)  # Convert softmax probabilities to class indices

# Generate the classification report
target_names = [f"Class {i}" for i in range(4)]  # Replace with actual class names if available
print(classification_report(y_test, y_pred_classes, target_names=target_names))
# Out:
# 21/21 [==============================] - 0s 16ms/step
#               precision    recall  f1-score   support
#
#      Class 0       0.88      0.48      0.62       124
#      Class 1       0.76      0.95      0.84       196
#      Class 2       0.98      0.98      0.98       182
#      Class 3       0.96      1.00      0.98       150
#
#     accuracy                           0.88       652
#    macro avg       0.89      0.85      0.85       652
# weighted avg       0.89      0.88      0.87       652

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 238, 238, 32)      896
#
#  max_pooling2d_7 (MaxPooling  (None, 119, 119, 32)     0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 117, 117, 64)      18496
#
#  max_pooling2d_8 (MaxPooling  (None, 58, 58, 64)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 56, 56, 128)       73856
#
#  max_pooling2d_9 (MaxPooling  (None, 28, 28, 128)      0
#  2D)
#
#  flatten_4 (Flatten)         (None, 100352)            0
#
#  dense_31 (Dense)            (None, 256)               25690368
#
#  dropout_27 (Dropout)        (None, 256)               0
#
#  dense_32 (Dense)            (None, 128)               32896
#
#  dropout_28 (Dropout)        (None, 128)               0
#
#  dense_33 (Dense)            (None, 4)                 516
#
# =================================================================
# Total params: 25,817,028
# Trainable params: 25,817,028
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, show_shapes=True, show_layer_names=False)

# %%
visualkeras.layered_view(model, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=924x1306>

# %%
import tensorflow as tf
from keras.models import load_model
custom_objects = {
    "Patches": Patches,
    "PatchEncoder": PatchEncoder,
}

#custom_objects = {"Patches": Patches}
#custom_objects = {"PatchEncoder": PatchEncoder}

# Load the saved VIT and CNN models
vit_model = tf.keras.models.load_model("/kaggle/working/vit.h5",custom_objects=custom_objects)
cnn_model = tf.keras.models.load_model("/kaggle/working/cnn1.h5")

# Make predictions on the test set using both models
vit_predictions = vit_model.predict(x_test)
cnn_predictions = cnn_model.predict(x_test)

# Define the weights for the ensemble (you can adjust these values based on your preference)
vit_weight = 0.6
cnn_weight = 0.4

# Combine the predictions using the weighted ensemble
ensemble_predictions = vit_weight * vit_predictions + cnn_weight * cnn_predictions

# Get the class indices with the highest probability for each sample
ensemble_pred_classes = np.argmax(ensemble_predictions, axis=1)

# Evaluate the ensemble's performance on the test set
from sklearn.metrics import accuracy_score, classification_report

ensemble_accuracy = accuracy_score(y_test, ensemble_pred_classes)
print(f"Ensemble Accuracy: {ensemble_accuracy}")

# Generate the classification report for the ensemble
target_names = [f"Class {i}" for i in range(4)]  # Replace with actual class names if available
print(classification_report(y_test, ensemble_pred_classes, target_names=target_names))
# Out:
# 21/21 [==============================] - 2s 31ms/step
# 21/21 [==============================] - 0s 15ms/step
# Ensemble Accuracy: 0.9938650306748467
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.99      0.99       124
#      Class 1       1.00      0.99      0.99       196
#      Class 2       0.99      0.99      0.99       182
#      Class 3       0.99      1.00      1.00       150
#
#     accuracy                           0.99       652
#    macro avg       0.99      0.99      0.99       652
# weighted avg       0.99      0.99      0.99       652
